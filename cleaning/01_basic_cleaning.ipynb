# %% [markdown]
# # Basic Cleaning of BG-Data

# %% [markdown]
# Say you just want to work with some of the data from the BG full dataset to test some hypotheses or just do some exploratory data analysis work. If that is the case, this notebook will help you accomplish that very fast, by the end of this notebook, you should have a full dataset ready for analysis.

# %% [markdown]
# # Packages

# %%
import numpy as np
import pandas as pd
from glob import glob
import re
import matplotlib.pyplot as plt
import nltk
import seaborn as sns
import concurrent.futures as cf
import csv
csv.field_size_limit(10000000)

pd.set_option('display.max_columns', None)

# %matplotlib inline

csv.field_size_limit()
# Out:
# 10000000

# %%
# Where is the data at?
path_raw_data = '~/Dropbox/Burning Glass/Data/random_data/'
# Where will it go to once it's cleaned?
path_out_clean = '~/Dropbox/Burning Glass/Analysis/unsupervised_approach/'

# %% [markdown]
# ## Columns and Data Types
#
# I have thoroughtly examined each column in the dataset and determined that the columns below are the most useful for analysis. If you'd like to load the entire dataset with all of the columns, make sure you don't run the cell below and comment out the parameter `use_cols=` from the `read_csv()` method below.

# %%
best_list = ['JobID', 'CleanJobTitle', 'CanonCity', 'CanonState', 'JobDate', 'JobText', 'Source', 'CanonEmployer',
             'Latitude', 'Longitude', 'CanonIntermediary', 'CanonJobTitle', 'CanonCounty', 'DivisionCode', 'MSA', 'LMA',
             'InternshipFlag', 'ConsolidatedONET', 'CanonSkillClusters', 'CanonSkills', 'IsDuplicate', 'CanonMinimumDegree', 
             'CanonRequiredDegrees', 'CIPCode', 'MinExperience', 'ConsolidatedInferredNAICS', 'BGTOcc', 'MaxAnnualSalary',
             'MaxHourlySalary', 'MinAnnualSalary', 'MinHourlySalary', 'YearsOfExperience', 'CanonJobHours', 'CanonJobType',
             'CanonPostalCode', 'CanonYearsOfExperienceCanonLevel', 'CanonYearsOfExperienceLevel', 'ConsolidatedTitle', 
             'Language', 'BGTSubOcc', 'ConsolidatedDegreeLevels', 'MaxDegreeLevel', 'MinDegreeLevel']

# %% [markdown]
# ## Single Data File
#
# If you are only using 1 file, you can load it using the following code.

# %%
# %%time

raw_data = 'rand_samp_20.csv'

df = pd.read_csv(path_raw_data + raw_data, 
                 parse_dates=['JobDate'], 
                 low_memory=False,
                 usecols=best_list
                 )
df.head()
# Out:
# CPU times: user 19.3 s, sys: 13.6 s, total: 32.9 s
# Wall time: 38.4 s
#          JobID                                  CleanJobTitle    CanonCity  \
# 0  38807273782    Business Development Manager - Construction       Irvine
# 1  38765089544                        Stihl Repair Technician       Tucson
# 2  38726367466  Pediatrics In - Academic Pediatric Geneticist       Fresno
# 3  38813841551                Ui Developer At The Judge Group       Irving
# 4  38799678091                    Cdl A Regional Truck Driver  Chestertown
#
#   CanonState    JobDate                                            JobText  \
# 0         CA 2020-07-03  Business Development Manager - Construction\n\...
# 1         AZ 2020-04-19  STIHL Repair Technician\n\nEquipmentLocator.co...
# 2         CA 2020-03-10  Pediatrics in CA - Academic Pediatric Genetici...
# 3         TX 2020-07-13  UI Developer at The Judge Group\n\nIrving, TX\...
# 4         MD 2020-06-20  CDL A Regional Truck Driver\n\nCowan Systems\n...
#
#              Source         CanonEmployer  Latitude  Longitude  \
# 0  Job intermediary                   NaN   33.7425  -117.7470
# 1         Job Board  Equipmentlocator Com   32.2161  -110.9710
# 2  Job intermediary                   NaN   36.8410  -119.8000
# 3  Job intermediary                   NaN   32.8420   -96.9719
# 4         Recruiter         Cowan Systems   39.2169   -76.0767
#
#                 CanonIntermediary                  CanonJobTitle CanonCounty  \
# 0              XO Staffing Agency           Construction Manager      Orange
# 1                             NaN              Repair Technician        Pima
# 2                      Comphealth                            NaN      Fresno
# 3  The Judge Group , Incorporated  User Interface (UI) Developer      Dallas
# 4                             NaN       Class A CDL Truck Driver        Kent
#
#    DivisionCode                                                MSA  \
# 0       11244.0  31080: Metropolitan Statistical Area|348: Comb...
# 1           NaN               46060: Metropolitan Statistical Area
# 2           NaN               23420: Metropolitan Statistical Area
# 3       19124.0  19100: Metropolitan Statistical Area|206: Comb...
# 4           NaN                                                NaN
#
#                  LMA  InternshipFlag  ConsolidatedONET  \
# 0  DV064204|MT063110               0        11202200.0
# 1           MT044606               0        49907100.0
# 2           MT062342               0        19102903.0
# 3  DV481912|MT481910               0        15113400.0
# 4           CN240290               0        53303200.0
#
#                                   CanonSkillClusters  \
# 0  Sales: Business Development;Specialized Skills...
# 1              Specialized Skills|Specialized Skills
# 2  Science and Research: Genetics;Specialized Ski...
# 3  Information Technology: JavaScript and jQuery;...
# 4      Administration: Scheduling;Specialized Skills
#
#                                          CanonSkills  IsDuplicate  \
# 0  {'Business Development': 'Sales: Business Deve...        False
# 1  {'Repair': 'Specialized Skills', 'Retail Indus...        False
# 2  {'Genetics': 'Science and Research: Genetics;S...        False
# 3  {'AngularJS': 'Information Technology: JavaScr...        False
# 4  {'Scheduling': 'Administration: Scheduling;Spe...        False
#
#   CanonMinimumDegree CanonRequiredDegrees               CIPCode  \
# 0         Bachelor's           Bachelor's  520201|521401|522001
# 1                NaN                  NaN                   NaN
# 2                NaN                  NaN                   NaN
# 3                NaN                  NaN                   NaN
# 4                NaN                  NaN                   NaN
#
#    MinExperience  ConsolidatedInferredNAICS      BGTOcc  MaxAnnualSalary  \
# 0            NaN                     2362.0  11-2022.00          88000.0
# 1            NaN                     5241.0  49-9071.91              NaN
# 2            NaN                       62.0  19-1020.01              NaN
# 3            8.0                       54.0  15-1134.93              NaN
# 4            3.0                      484.0  53-3032.00          65000.0
#
#    MaxHourlySalary  MinAnnualSalary  MinHourlySalary  \
# 0            42.31          63000.0            30.29
# 1              NaN              NaN              NaN
# 2              NaN              NaN              NaN
# 3              NaN              NaN              NaN
# 4            31.25          54000.0            25.96
#
#                        YearsOfExperience CanonJobHours CanonJobType  \
# 0                                    NaN           NaN          NaN
# 1                                    NaN      fulltime    permanent
# 2                                    NaN           NaN          NaN
# 3      Min 2 Years|min 1 Year|8-10 years      fulltime    temporary
# 4  one year|three years|One year|3 years           NaN          NaN
#
#   CanonPostalCode CanonYearsOfExperienceCanonLevel  \
# 0           92602                              NaN
# 1           85701                              NaN
# 2           93650                              NaN
# 3           75014                               6+
# 4           21620                              1-6
#
#   CanonYearsOfExperienceLevel  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                        high
# 4                         mid
#
#                                    ConsolidatedTitle Language  \
# 0                               Construction Manager       en
# 1                                  Repair Technician       en
# 2  Academic Pediatric Geneticist, Information And...       en
# 3                      User Interface (UI) Developer       en
# 4                           Class A CDL Truck Driver       en
#
#                                       BGTSubOcc ConsolidatedDegreeLevels  \
# 0                  Business Development Manager                       16
# 1  Building and General Maintenance Technician                       NaN
# 2                                     Biologist                      NaN
# 3                 User Interface (UI) Developer                      NaN
# 4                         Regional Truck Driver                      NaN
#
#    MaxDegreeLevel  MinDegreeLevel
# 0             NaN            16.0
# 1             NaN             NaN
# 2             NaN             NaN
# 3             NaN             NaN
# 4             NaN             NaN

# %% [markdown]
# ## Multiple Files
#
# If you want to analyze multiple files, and the combined size of the files are less than your memory RAM, use the following code.
#
# **Note**: If you want to clean many files that don't fit into memory (say 50GB), navigate to the cleaning data at scale notebook and use dask instead.

# %%
files = glob('../../../../Dropbox/Burning Glass/Data/random_data/ran*.csv')
files[:3]

# %%
# %%time

# You will create a function to read your CSV files
def get_data(data):
    return pd.read_csv(data, low_memory=False, parse_dates=['JobDate'], usecols=small_list)

# Then you will parallelize it to all the cores in your machine
# as you read the files
with cf.ProcessPoolExecutor() as executor:
    results = executor.map(get_data, files)

# concatenate all of the results together
df = pd.concat(results)

# reset the mismatched indexes and keep the changes
df.reset_index(drop=True, inplace=True)

# check it out
df.head(3)

# %% [markdown]
# # Examine the Data
#
# Now that we have our dataset ready, let's see where we are at in terms of missing values.

# %%
df.shape
# Out:
# (500000, 43)

# %%
df.tail()
# Out:
#               JobID                                      CleanJobTitle  \
# 499995  38791254071                 Registered Nurse/Travel Assignment
# 499996  38779945336                  Assistant Human Resources Manager
# 499997  38758065731                     Registered Nurse Senior Living
# 499998  38749146523      02 Night Cook & Prep - Gulf Coast Town Center
# 499999  38821741759  Patient Financial Coordinator - Certified Appl...
#
#             CanonCity CanonState    JobDate  \
# 499995  Moreno Valley         CA 2020-06-07
# 499996     Alpharetta         GA 2020-05-15
# 499997   Grand Rapids         MI 2020-04-07
# 499998     Fort Myers         FL 2020-03-29
# 499999     Des Moines         IA 2020-07-26
#
#                                                   JobText            Source  \
# 499995  Registered Nurse (RN) / Travel Assignment\n\nD...  Job intermediary
# 499996  Assistant HR Manager\n\nFamily Flowers - Alpha...         Job Board
# 499997  Job Details\n\n*\n\nRegistered Nurse (RN) FULL...         Job Board
# 499998                                                NaN         Job Board
# 499999  Patient Financial Coordinator - Certified Appl...         Education
#
#                     CanonEmployer  Latitude  Longitude  \
# 499995                        NaN   33.8885  -117.2220
# 499996             Family Flowers   34.1222   -84.2975
# 499997                  Samaritas   42.9664   -85.6552
# 499998  Zaxby's Southwest Florida   26.6285   -81.8674
# 499999          Methodist College   41.6050   -93.6319
#
#                       CanonIntermediary              CanonJobTitle  \
# 499995  Accountable Healthcare Staffing           Registered Nurse
# 499996                              NaN  Human Resources Assistant
# 499997                              NaN           Registered Nurse
# 499998                              NaN                  Prep Cook
# 499999                              NaN        Financial Counselor
#
#        CanonCounty  DivisionCode                                   MSA  \
# 499995   Riverside           NaN  40140: Metropolitan Statistical Area
# 499996      Fulton           NaN  12060: Metropolitan Statistical Area
# 499997        Kent           NaN  24340: Metropolitan Statistical Area
# 499998         Lee           NaN  15980: Metropolitan Statistical Area
# 499999        Polk           NaN  19780: Metropolitan Statistical Area
#
#              LMA  InternshipFlag  ConsolidatedONET  \
# 499995  MT064014               0        29114100.0
# 499996  MT131206               0        11312100.0
# 499997  MT262434               0        29114100.0
# 499998  MT121598               0        35201400.0
# 499999  MT191978               0        43405103.0
#
#                                        CanonSkillClusters  \
# 499995  Health Care: Basic Living Activities Support;S...
# 499996  Business: Business Strategy;Specialized Skills...
# 499997  Administration: Administrative Support;Special...
# 499998                                 Specialized Skills
# 499999  Human Resources: Compensation and Benefits;Spe...
#
#                                               CanonSkills  IsDuplicate  \
# 499995  {'Caregiving': 'Health Care: Basic Living Acti...        False
# 499996  {'Business Strategy': 'Business: Business Stra...        False
# 499997  {'Appointment Setting': 'Administration: Admin...        False
# 499998            {'Multi-Tasking': 'Specialized Skills'}        False
# 499999  {'COBRA': 'Human Resources: Compensation and B...        False
#
#        CanonMinimumDegree    CanonRequiredDegrees CIPCode  MinExperience  \
# 499995                NaN                     NaN     NaN            NaN
# 499996                NaN                     NaN     NaN            NaN
# 499997        Associate's  Associate's|Bachelor's     NaN            1.0
# 499998                NaN                     NaN     NaN            NaN
# 499999        Associate's  Associate's|Bachelor's     NaN            5.0
#
#         ConsolidatedInferredNAICS      BGTOcc  MaxAnnualSalary  \
# 499995                       62.0  29-1141.00              NaN
# 499996                     4531.0  11-3121.92          55000.0
# 499997                       62.0  29-1141.00              NaN
# 499998                      722.0  35-2011.00              NaN
# 499999                     8131.0  43-4051.03              NaN
#
#         MaxHourlySalary  MinAnnualSalary  MinHourlySalary YearsOfExperience  \
# 499995              NaN              NaN              NaN               NaN
# 499996            26.44          40000.0            19.23           2 years
# 499997              NaN              NaN              NaN          One year
# 499998              NaN              NaN              NaN               NaN
# 499999              NaN              NaN              NaN           5 years
#
#        CanonJobHours CanonJobType CanonPostalCode  \
# 499995           NaN          NaN           92551
# 499996      fulltime    permanent           30004
# 499997           NaN          NaN           49501
# 499998           NaN          NaN           33901
# 499999      fulltime    permanent           50301
#
#        CanonYearsOfExperienceCanonLevel CanonYearsOfExperienceLevel  \
# 499995                              NaN                         NaN
# 499996                              NaN                         NaN
# 499997                              0-1                         low
# 499998                              NaN                         NaN
# 499999                              1-6                         mid
#
#                 ConsolidatedTitle Language  \
# 499995           Registered Nurse       en
# 499996  Human Resources Assistant       en
# 499997           Registered Nurse       en
# 499998                  Prep Cook       en
# 499999        Financial Counselor       en
#
#                                          BGTSubOcc ConsolidatedDegreeLevels  \
# 499995                            Registered Nurse                      NaN
# 499996                     Human Resources Manager                      NaN
# 499997                            Registered Nurse                    14|16
# 499998                                        Cook                      NaN
# 499999  Registrar / Patient Service Representative                    14|16
#
#         MaxDegreeLevel  MinDegreeLevel
# 499995             NaN             NaN
# 499996             NaN             NaN
# 499997            16.0            14.0
# 499998             NaN             NaN
# 499999            16.0            14.0

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 43 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   JobID                             500000 non-null  int64
#  1   CleanJobTitle                     499957 non-null  object
#  2   CanonCity                         497366 non-null  object
#  3   CanonState                        499771 non-null  object
#  4   JobDate                           500000 non-null  datetime64[ns]
#  5   JobText                           468540 non-null  object
#  6   Source                            494214 non-null  object
#  7   CanonEmployer                     397265 non-null  object
#  8   Latitude                          497587 non-null  float64
#  9   Longitude                         497587 non-null  float64
#  10  CanonIntermediary                 61109 non-null   object
#  11  CanonJobTitle                     318432 non-null  object
#  12  CanonCounty                       497350 non-null  object
#  13  DivisionCode                      157884 non-null  float64
#  14  MSA                               485595 non-null  object
#  15  LMA                               495860 non-null  object
#  16  InternshipFlag                    500000 non-null  int64
#  17  ConsolidatedONET                  482008 non-null  float64
#  18  CanonSkillClusters                474783 non-null  object
#  19  CanonSkills                       500000 non-null  object
#  20  IsDuplicate                       500000 non-null  bool
#  21  CanonMinimumDegree                254649 non-null  object
#  22  CanonRequiredDegrees              226371 non-null  object
#  23  CIPCode                           84024 non-null   object
#  24  MinExperience                     222730 non-null  float64
#  25  ConsolidatedInferredNAICS         374719 non-null  float64
#  26  BGTOcc                            466967 non-null  object
#  27  MaxAnnualSalary                   151696 non-null  float64
#  28  MaxHourlySalary                   151696 non-null  float64
#  29  MinAnnualSalary                   151696 non-null  float64
#  30  MinHourlySalary                   151696 non-null  float64
#  31  YearsOfExperience                 284071 non-null  object
#  32  CanonJobHours                     253346 non-null  object
#  33  CanonJobType                      260885 non-null  object
#  34  CanonPostalCode                   495490 non-null  object
#  35  CanonYearsOfExperienceCanonLevel  235198 non-null  object
#  36  CanonYearsOfExperienceLevel       235198 non-null  object
#  37  ConsolidatedTitle                 499957 non-null  object
#  38  Language                          500000 non-null  object
#  39  BGTSubOcc                         466948 non-null  object
#  40  ConsolidatedDegreeLevels          254649 non-null  object
#  41  MaxDegreeLevel                    83675 non-null   float64
#  42  MinDegreeLevel                    254649 non-null  float64
# dtypes: bool(1), datetime64[ns](1), float64(12), int64(2), object(27)
# memory usage: 2.7 GB

# %%
missing_pct = df.isna().sum() / df.shape[0] * 100
missing_pct
# Out:
# JobID                                0.0000
# CleanJobTitle                        0.0086
# CanonCity                            0.5268
# CanonState                           0.0458
# JobDate                              0.0000
# JobText                              6.2920
# Source                               1.1572
# CanonEmployer                       20.5470
# Latitude                             0.4826
# Longitude                            0.4826
# CanonIntermediary                   87.7782
# CanonJobTitle                       36.3136
# CanonCounty                          0.5300
# DivisionCode                        68.4232
# MSA                                  2.8810
# LMA                                  0.8280
# InternshipFlag                       0.0000
# ConsolidatedONET                     3.5984
# CanonSkillClusters                   5.0434
# CanonSkills                          0.0000
# IsDuplicate                          0.0000
# CanonMinimumDegree                  49.0702
# CanonRequiredDegrees                54.7258
# CIPCode                             83.1952
# MinExperience                       55.4540
# ConsolidatedInferredNAICS           25.0562
# BGTOcc                               6.6066
# MaxAnnualSalary                     69.6608
# MaxHourlySalary                     69.6608
# MinAnnualSalary                     69.6608
# MinHourlySalary                     69.6608
# YearsOfExperience                   43.1858
# CanonJobHours                       49.3308
# CanonJobType                        47.8230
# CanonPostalCode                      0.9020
# CanonYearsOfExperienceCanonLevel    52.9604
# CanonYearsOfExperienceLevel         52.9604
# ConsolidatedTitle                    0.0086
# Language                             0.0000
# BGTSubOcc                            6.6104
# ConsolidatedDegreeLevels            49.0702
# MaxDegreeLevel                      83.2650
# MinDegreeLevel                      49.0702
# dtype: float64

# %% [markdown]
# We have lots of missing values so let's begin by dealing with the columns which we probably can't go on without, these are `JobText` and `CanonEmployer`. The first thing we will do is to filter out observations without a job posting.

# %%
df = df[df['JobText'].notnull()]

# %% [markdown]
# The next thing we'll do is to determine which samples don't have a value in the var `CanonEmployer` but do have one in `CanonIntermediary`. What we'll do is to fill in those with an intermediary with the value `"Recruiting Agency"`.

# %%
df.loc[(df['CanonEmployer'].isna()) & (df['CanonIntermediary'].notna()), ['CanonEmployer', 'CanonIntermediary']].head()
# Out:
#    CanonEmployer               CanonIntermediary
# 0            NaN              XO Staffing Agency
# 2            NaN                      Comphealth
# 3            NaN  The Judge Group , Incorporated
# 11           NaN                         Aerotek
# 31           NaN                        Randstad

# %%
print(f'Missing companies BEFORE adding the Recruitment Agencies: {df.CanonEmployer.isna().sum()}')
# Out:
# Missing companies BEFORE adding the Recruitment Agencies: 93808

# %%
df.loc[(df['CanonEmployer'].isna()) & (df['CanonIntermediary'].notna()), 'CanonEmployer'] = 'Recruiting Agency'

print(f'Missing companies AFTER adding the Recruitment Agencies: {df.CanonEmployer.isna().sum()}')
# Out:
# Missing companies AFTER adding the Recruitment Agencies: 36897

# %% [markdown]
# Many jobs without an employer or recruiting agency do have a the employer in the job description. Take a look at the following example.

# %%
df.loc[df['CanonEmployer'].isna(), ["CleanJobTitle", "JobText"]].head()
# Out:
#                                         CleanJobTitle  \
# 23                                          Bartender
# 40                      Security Officer - Healthcare
# 55                                  Hedis Coordinator
# 57                        Housekeeping Room Inspector
# 67  Bookkeeper, E-Commerce, Data Entry, Excel Prof...
#
#                                               JobText
# 23  Bartender\n\nposted February 8, 2020\n\nHyatt ...
# 40  Security Officer - Healthcare\n\nSECURITAS -\n...
# 55  HEDIS Coordinator\n\nHealthCare Support Staffi...
# 57  Housekeeping Room Inspector\n\nHEI Hotels in S...
# 67  Bookkeeper, Ecommerce, Data Entry, Excel Profe...

# %%
df.loc[df['CanonEmployer'].isna(), "JobText"].iloc[0]
# Out:
# 'Bartender\n\nposted February 8, 2020\n\nHyatt House San Diego/Sorrento Mesa\nSan Diego, CA Apply\n\nEmail Facebook Tweet LinkedIn\n\nLogo for Hyatt House San Diego/Sorrento Mesa\n\nLogo for Hyatt House San Diego/Sorrento Mesa\n\nHyatt House San Diego/Sorrento Mesa\n\n360811 l\n\nAbout This Job\n\nDescription\n\nHYATT house is an extended-stay, residential-style hotel that aims to provide individual travelers with the feel of a modern condominium. The 125 to 200 room, all-suite properties offer comforts of home such as fully equipped kitchens, flat panel HDTVs and free high-speed internet access. The public space features facilities such as a pool, a fitness center, a business center, a full breakfast every morning and the HBar in the evening. HYATT house properties are located in urban, airport and suburban locations and can accommodate small corporate meetings and corporate clients seeking to place their employees on extended assignment.\n\nBartenders are responsible for providing libations and offering customized recommendations. The right person should be familiar with the latest in mixology, bar equipment, and sanitation standards, with a focus on maintaining an attractive bar. This position offers opportunity for casual conversation, creativity and allows for building on ones style and previous bartending experiences. Preferred candidates will have understanding of state and local serving guidelines. This is a beginners start into bartending.\n\nWelcome you to our new house, HYATT house!\n\nQualifications\n\n* A true desire to satisfy the needs of others in a fast paced environment.\n* Refined verbal communication skills.\n* Must have physical stamina to lift moderate amounts of weight.\n* Willingness to multitask and assist in the kitchen if needed.'

# %% [markdown]
# If you would like to remove observations without an employer, run the following cell. Otherwise, make sure you skip it.

# %%
df = df[df['CanonEmployer'].notnull()]

# %% [markdown]
# If you would like to add the occupations names, you can do so by running the following cells.

# %%
df.shape
# Out:
# (431643, 43)

# %%
# %%time

# first get rid of observations without a sa
# df = df[df['BGTOcc'].notna()].copy()
df.loc[df['BGTOcc'].notnull(), 'BGTOcc'] = df.loc[df['BGTOcc'].notnull(), 'BGTOcc'].str.replace('-', '').astype(np.float32).astype(np.int32)
df['BGTOcc'].head()
# Out:
# CPU times: user 228 ms, sys: 28.1 ms, total: 256 ms
# Wall time: 257 ms
# 0    112022
# 1    499071
# 2    191020
# 3    151134
# 4    533032
# Name: BGTOcc, dtype: object

# %% [markdown]
# Load the occupations data.

# %%
occupations_df = pd.read_csv('~/Dropbox/Burning Glass/Analysis/occupations_clean.csv',
                             dtype={'occu_code': np.int32, 'occu_text': np.str})
occupations_df.head()
# Out:
#    occu_code                                  occu_text
# 0     110000                     Management Occupations
# 1     112022                             Sales Managers
# 2     113021  Computer and Information Systems Managers
# 3     113131          Training and Development Managers
# 4     119021                      Construction Managers

# %%
# %%time

new_df = df.merge(occupations_df, 
                  left_on='BGTOcc', 
                  right_on='occu_code', 
                  how='left')
new_df.head()
# Out:
# CPU times: user 1.72 s, sys: 350 ms, total: 2.07 s
# Wall time: 2.16 s
#          JobID                                  CleanJobTitle    CanonCity  \
# 0  38807273782    Business Development Manager - Construction       Irvine
# 1  38765089544                        Stihl Repair Technician       Tucson
# 2  38726367466  Pediatrics In - Academic Pediatric Geneticist       Fresno
# 3  38813841551                Ui Developer At The Judge Group       Irving
# 4  38799678091                    Cdl A Regional Truck Driver  Chestertown
#
#   CanonState    JobDate                                            JobText  \
# 0         CA 2020-07-03  Business Development Manager - Construction\n\...
# 1         AZ 2020-04-19  STIHL Repair Technician\n\nEquipmentLocator.co...
# 2         CA 2020-03-10  Pediatrics in CA - Academic Pediatric Genetici...
# 3         TX 2020-07-13  UI Developer at The Judge Group\n\nIrving, TX\...
# 4         MD 2020-06-20  CDL A Regional Truck Driver\n\nCowan Systems\n...
#
#              Source         CanonEmployer  Latitude  Longitude  \
# 0  Job intermediary     Recruiting Agency   33.7425  -117.7470
# 1         Job Board  Equipmentlocator Com   32.2161  -110.9710
# 2  Job intermediary     Recruiting Agency   36.8410  -119.8000
# 3  Job intermediary     Recruiting Agency   32.8420   -96.9719
# 4         Recruiter         Cowan Systems   39.2169   -76.0767
#
#                 CanonIntermediary                  CanonJobTitle CanonCounty  \
# 0              XO Staffing Agency           Construction Manager      Orange
# 1                             NaN              Repair Technician        Pima
# 2                      Comphealth                            NaN      Fresno
# 3  The Judge Group , Incorporated  User Interface (UI) Developer      Dallas
# 4                             NaN       Class A CDL Truck Driver        Kent
#
#    DivisionCode                                                MSA  \
# 0       11244.0  31080: Metropolitan Statistical Area|348: Comb...
# 1           NaN               46060: Metropolitan Statistical Area
# 2           NaN               23420: Metropolitan Statistical Area
# 3       19124.0  19100: Metropolitan Statistical Area|206: Comb...
# 4           NaN                                                NaN
#
#                  LMA  InternshipFlag  ConsolidatedONET  \
# 0  DV064204|MT063110               0        11202200.0
# 1           MT044606               0        49907100.0
# 2           MT062342               0        19102903.0
# 3  DV481912|MT481910               0        15113400.0
# 4           CN240290               0        53303200.0
#
#                                   CanonSkillClusters  \
# 0  Sales: Business Development;Specialized Skills...
# 1              Specialized Skills|Specialized Skills
# 2  Science and Research: Genetics;Specialized Ski...
# 3  Information Technology: JavaScript and jQuery;...
# 4      Administration: Scheduling;Specialized Skills
#
#                                          CanonSkills  IsDuplicate  \
# 0  {'Business Development': 'Sales: Business Deve...        False
# 1  {'Repair': 'Specialized Skills', 'Retail Indus...        False
# 2  {'Genetics': 'Science and Research: Genetics;S...        False
# 3  {'AngularJS': 'Information Technology: JavaScr...        False
# 4  {'Scheduling': 'Administration: Scheduling;Spe...        False
#
#   CanonMinimumDegree CanonRequiredDegrees               CIPCode  \
# 0         Bachelor's           Bachelor's  520201|521401|522001
# 1                NaN                  NaN                   NaN
# 2                NaN                  NaN                   NaN
# 3                NaN                  NaN                   NaN
# 4                NaN                  NaN                   NaN
#
#    MinExperience  ConsolidatedInferredNAICS  BGTOcc  MaxAnnualSalary  \
# 0            NaN                     2362.0  112022          88000.0
# 1            NaN                     5241.0  499071              NaN
# 2            NaN                       62.0  191020              NaN
# 3            8.0                       54.0  151134              NaN
# 4            3.0                      484.0  533032          65000.0
#
#    MaxHourlySalary  MinAnnualSalary  MinHourlySalary  \
# 0            42.31          63000.0            30.29
# 1              NaN              NaN              NaN
# 2              NaN              NaN              NaN
# 3              NaN              NaN              NaN
# 4            31.25          54000.0            25.96
#
#                        YearsOfExperience CanonJobHours CanonJobType  \
# 0                                    NaN           NaN          NaN
# 1                                    NaN      fulltime    permanent
# 2                                    NaN           NaN          NaN
# 3      Min 2 Years|min 1 Year|8-10 years      fulltime    temporary
# 4  one year|three years|One year|3 years           NaN          NaN
#
#   CanonPostalCode CanonYearsOfExperienceCanonLevel  \
# 0           92602                              NaN
# 1           85701                              NaN
# 2           93650                              NaN
# 3           75014                               6+
# 4           21620                              1-6
#
#   CanonYearsOfExperienceLevel  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                        high
# 4                         mid
#
#                                    ConsolidatedTitle Language  \
# 0                               Construction Manager       en
# 1                                  Repair Technician       en
# 2  Academic Pediatric Geneticist, Information And...       en
# 3                      User Interface (UI) Developer       en
# 4                           Class A CDL Truck Driver       en
#
#                                       BGTSubOcc ConsolidatedDegreeLevels  \
# 0                  Business Development Manager                       16
# 1  Building and General Maintenance Technician                       NaN
# 2                                     Biologist                      NaN
# 3                 User Interface (UI) Developer                      NaN
# 4                         Regional Truck Driver                      NaN
#
#    MaxDegreeLevel  MinDegreeLevel  occu_code  \
# 0             NaN            16.0   112022.0
# 1             NaN             NaN   499071.0
# 2             NaN             NaN        NaN
# 3             NaN             NaN   151134.0
# 4             NaN             NaN   533032.0
#
#                                  occu_text
# 0                           Sales Managers
# 1  Maintenance and Repair Workers, General
# 2                                      NaN
# 3                           Web Developers
# 4  Heavy and Tractor-Trailer Truck Drivers

# %%
new_df.shape
# Out:
# (431643, 45)
